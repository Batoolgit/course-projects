# %%
import numpy as np
import matplotlib.pyplot as plt
import decay_v3 as dc
import growth as gr

# %%
theta = 1
I = 0.1
a=-1
T= 10

dt=0.1
dt_array = [0.1, 0.5, 1, 2] 
dc.plot_numerical_and_exact(theta, I, a, T, dt)

# %%
dt_array = [0.1, 0.5, 1, 2] 
theta=0
gr.plot_numerical_and_exact_multiple(theta, I, a, T, dt_array)
